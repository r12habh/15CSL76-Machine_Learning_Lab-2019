# %% [markdown]
# #Lab 8

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
iris=load_iris()
x=pd.DataFrame(iris.data, columns=iris.feature_names)
y=pd.DataFrame(iris.target, columns=['target'])
x.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
colormap=np.array(['red','blue','green'])

# %%
plt.title('Actual Clusters')
plt.scatter(x['sepal width (cm)'], x['petal width (cm)'], c=colormap[y.target])
plt.xlabel('sepal width (cm)')
plt.ylabel('petal width (cm)')
# Out:
# Text(0, 0.5, 'petal width (cm)')

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=3).fit(x)
plt.scatter(x['sepal length (cm)'], x['petal width (cm)'], c=colormap[km.labels_])
plt.xlabel('sepal length (cm)')
plt.ylabel('petal width (cm)')
plt.title('KMeans Clusters')
# Out:
# Text(0.5, 1.0, 'KMeans Clusters')

# %%
from sklearn.mixture import GaussianMixture
gm = GaussianMixture(n_components=3).fit(x).predict(x)
plt.scatter(x['sepal width (cm)'], x['petal width (cm)'], c=colormap[gm])
plt.xlabel('sepal width (cm)')
plt.ylabel('petal width (cm)')
plt.title('GaussianMixture Clusters')
# Out:
# Text(0.5, 1.0, 'GaussianMixture Clusters')

# %%
from sklearn import metrics as m
print("KMeans Accuracy: ", m.accuracy_score(y, km.labels_))
print("Gausian Mixture: ", m.accuracy_score(y, gm))
# Out:
# KMeans Accuracy:  0.8933333333333333
# Gausian Mixture:  0.9666666666666667
